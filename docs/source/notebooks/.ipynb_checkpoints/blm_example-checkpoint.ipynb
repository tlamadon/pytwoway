# %% [markdown]
# # BLM example

# %%
# Add PyTwoWay to system path (SET THESE TO WHERE YOU HAVE THE PACKAGE REPOSITORIES CLONED)
import sys
sys.path.append('../../..')

# %%
# Import the PyTwoWay package 
# (Make sure you have installed it using pip install pytwoway)
import numpy as np
import bipartitepandas as bpd
import pytwoway as tw
from pytwoway import constraints as cons
from matplotlib import pyplot as plt

# %% [markdown]
# ## First, check out parameter options

# %%
print('----- BLM -----')
tw.blm_params().describe_all()
print('----- Clustering -----')
bpd.cluster_params().describe_all()
print('----- Cleaning -----')
bpd.clean_params().describe_all()
print('----- Simulation -----')
bpd.sim_params().describe_all()
# Out:
# ----- BLM -----
# KEY: 'nl'
# CURRENT VALUE: 6
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=6) Number of worker types.
#
# KEY: 'nk'
# CURRENT VALUE: 10
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=10) Number of firm types.
#
# KEY: 'categorical_controls'
# CURRENT VALUE: None
# VALID VALUES: None or dictionary of type <class 'bipartitepandas.util.ParamsDict'>
# DESCRIPTION:
#             (default=None) Dictionary linking column names to instances of tw.categorical_control_params(). Each instance specifies a new categorical control variable and how its starting values should be generated. Run tw.categorical_control_params().describe_all() for descriptions of all valid parameters for simulating each control variable. None is equivalent to {}.
#
# KEY: 'continuous_controls'
# CURRENT VALUE: None
# VALID VALUES: None or dictionary of type <class 'bipartitepandas.util.ParamsDict'>
# DESCRIPTION:
#             (default=None) Dictionary linking column names to instances of tw.continuous_control_params(). Each instance specifies a new continuous control variable and how its starting values should be generated. Run tw.continuous_control_params().describe_all() for descriptions of all valid parameters for simulating each control variable. None is equivalent to {}.
#
# KEY: 'a1_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of simulated A1 (mean of fixed effects in first period).
#
# KEY: 'a1_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of simulated A1 (mean of fixed effects in first period).
#
# KEY: 'a2_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of simulated A2 (mean of fixed effects in second period).
#
# KEY: 'a2_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of simulated A2 (mean of fixed effects in second period).
#
# KEY: 's1_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of simulated S1 (standard deviation of fixed effects in first period).
#
# KEY: 's1_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of simulated S1 (standard deviation of fixed effects in first period).
#
# KEY: 's2_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of simulated S2 (standard deviation of fixed effects in second period).
#
# KEY: 's2_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of simulated S2 (standard deviation of fixed effects in second period).
#
# KEY: 'pk1_prior'
# CURRENT VALUE: None
# VALID VALUES: None or array of datatype (('float', 'int'), <function _min_gt0 at 0x7fb2544e7820>)
# CONSTRAINTS: 'min > 0'
# DESCRIPTION:
#             (default=None) Dirichlet prior for pk1 (probability of being at each combination of firm types for movers). Must have length nl. None is equivalent to np.ones(nl).
#
# KEY: 'pk0_prior'
# CURRENT VALUE: None
# VALID VALUES: None or array of datatype (('float', 'int'), <function _min_gt0 at 0x7fb2544e7820>)
# CONSTRAINTS: 'min > 0'
# DESCRIPTION:
#             (default=None) Dirichlet prior for pk0 (probability of being at each firm type for stayers). Must have length nl. None is equivalent to np.ones(nl).
#
# KEY: 'verbose'
# CURRENT VALUE: 0
# VALID VALUES: one of [0, 1, 2]
# DESCRIPTION:
#             (default=0) If 0, print no output; if 1, print additional output; if 2, print maximum output.
#
# KEY: 'return_qi'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, return qi matrix after first loop.
#
# KEY: 'n_iters_movers'
# CURRENT VALUE: 100
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=100) Number of iterations for EM for movers.
#
# KEY: 'threshold_movers'
# CURRENT VALUE: 1e-07
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1e-7) Threshold to break EM loop for movers.
#
# KEY: 'update_a'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If False, do not update A1 or A2.
#
# KEY: 'update_s'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If False, do not update S1 or S2.
#
# KEY: 'update_pk1'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If False, do not update pk1.
#
# KEY: 'cons_a'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on A1 and A2. None is equivalent to [].
#
# KEY: 'cons_s'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on S1 and S2. None is equivalent to [].
#
# KEY: 'cons_a_all'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on A1/A2/A1_cat/A2_cat/A1_cts/A2_cts. None is equivalent to [].
#
# KEY: 'cons_s_all'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on S1/S2/S1_cat/S2_cat/S1_cts/S2_cts. None is equivalent to [].
#
# KEY: 's_lower_bound'
# CURRENT VALUE: 1e-10
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '> 0'
# DESCRIPTION:
#             (default=1e-10) Lower bound on estimated S1/S2/S1_cat/S2_cat/S1_cts/S2_cts.
#
# KEY: 'd_prior_movers'
# CURRENT VALUE: 1.0001
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=1.0001) Account for probabilities being too small by adding (d_prior - 1) to pk1.
#
# KEY: 'n_iters_stayers'
# CURRENT VALUE: 100
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=100) Number of iterations for EM for stayers.
#
# KEY: 'threshold_stayers'
# CURRENT VALUE: 1e-07
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1e-7) Threshold to break EM loop for stayers.
#
# KEY: 'd_prior_stayers'
# CURRENT VALUE: 1.0001
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=1.0001) Account for probabilities being too small by adding (d_prior - 1) to pk0.
#
# ----- Clustering -----
# KEY: 'measures'
# CURRENT VALUE: <bipartitepandas.measures.measures.CDFs object at 0x7fb25352d040>
# VALID VALUES: one of or list of type (<class 'bipartitepandas.measures.measures.CDFs'>, <class 'bipartitepandas.measures.measures.Moments'>)
# DESCRIPTION:
#             (default=bpd.measures.CDFs()) How to compute measures for clustering. Options can be seen in bipartitepandas.measures.
#
# KEY: 'grouping'
# CURRENT VALUE: <bipartitepandas.grouping.grouping.KMeans object at 0x7fb25352d070>
# VALID VALUES: one of type (<class 'bipartitepandas.grouping.grouping.KMeans'>, <class 'bipartitepandas.grouping.grouping.Quantiles'>)
# DESCRIPTION:
#             (default=bpd.grouping.KMeans()) How to group firms based on measures. Options can be seen in bipartitepandas.grouping.
#
# KEY: 'stayers_movers'
# CURRENT VALUE: None
# VALID VALUES: one of [None, 'stayers', 'movers']
# DESCRIPTION:
#             (default=None) If None, clusters on entire dataset; if 'stayers', clusters on only stayers; if 'movers', clusters on only movers; if 'stays', clusters on only stays; if 'moves', clusters on only moves.
#
# KEY: 't'
# CURRENT VALUE: None
# VALID VALUES: None or one of type (<class 'int'>, <class 'list'>)
# DESCRIPTION:
#             (default=None) If None, clusters on entire dataset; if int, gives period in data to consider (only valid for non-collapsed data); if list of int, gives periods in data to consider (only valid for non-collapsed data).
#
# KEY: 'weighted'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If True, weight firm clusters by firm size (if a weight column is included, firm weight is computed using this column; otherwise, each observation is given weight 1).
#
# KEY: 'dropna'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, drop observations where firms aren't clustered; if False, keep all observations.
#
# KEY: 'clean_params'
# CURRENT VALUE: None
# VALID VALUES: None or one of type <class 'bipartitepandas.util.ParamsDict'>
# DESCRIPTION:
#             (default=None) Dictionary of parameters for cleaning. This is used when observations get dropped because they were not clustered. Default is None, which sets connectedness to be the connectedness measure previously used. Run bpd.clean_params().describe_all() for descriptions of all valid parameters.
#
# KEY: 'is_sorted'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) For event study format. If False, dataframe will be sorted by i (and t, if included). Returned dataframe is not guaranteed to be sorted if original dataframe is not sorted. Sorting may alter original dataframe if copy is set to False. Set is_sorted to True if dataframe is already sorted.
#
# KEY: 'copy'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If False, avoid copy.
#
# ----- Cleaning -----
# KEY: 'connectedness'
# CURRENT VALUE: None
# VALID VALUES: one of ['connected', 'leave_out_observation', 'leave_out_spell', 'leave_out_match', 'leave_out_worker', 'leave_out_firm', None]
# DESCRIPTION:
#             (default=None) When computing largest connected set of firms: if 'connected', keep observations in the largest connected set of firms; if 'leave_out_observation', keep observations in the largest leave-one-observation-out connected set; if 'leave_out_spell', keep observations in the largest leave-one-spell-out connected set; if 'leave_out_match', keep observations in the largest leave-one-match-out connected set; if 'leave_out_worker', keep observations in the largest leave-one-worker-out connected set; if 'leave_out_firm', keep observations in the largest leave-one-firm-out connected set; if None, keep all observations.
#
# KEY: 'component_size_variable'
# CURRENT VALUE: 'firms'
# VALID VALUES: one of ['len', 'length', 'firms', 'workers', 'stayers', 'movers', 'firms_plus_workers', 'firms_plus_stayers', 'firms_plus_movers', 'len_stayers', 'length_stayers', 'len_movers', 'length_movers', 'stays', 'moves']
# DESCRIPTION:
#         (default='firms') How to determine largest connected component. Options are 'len'/'length' (length of frames), 'firms' (number of unique firms), 'workers' (number of unique workers), 'stayers' (number of unique stayers), 'movers' (number of unique movers), 'firms_plus_workers' (number of unique firms + number of unique workers), 'firms_plus_stayers' (number of unique firms + number of unique stayers), 'firms_plus_movers' (number of unique firms + number of unique movers), 'len_stayers'/'length_stayers' (number of stayer observations), 'len_movers'/'length_movers' (number of mover observations), 'stays' (number of stay observations), and 'moves' (number of move observations).
#
# KEY: 'i_t_how'
# CURRENT VALUE: 'max'
# VALID VALUES: one of type (<class 'builtin_function_or_method'>, <class 'function'>, <class 'method'>, <class 'str'>)
# DESCRIPTION:
#             (default='max') When dropping i-t duplicates: if 'max', keep max paying job; otherwise, take `i_t_how` over duplicate worker-firm-year observations, then take the highest paying worker-firm observation. `i_t_how` can take any input valid for a Pandas transform. Note that if multiple time and/or firm columns are included (as in collapsed long and event study formats), then data is converted to long, cleaned, then converted back to its original format.
#
# KEY: 'drop_returns'
# CURRENT VALUE: False
# VALID VALUES: one of [False, 'returns', 'returners', 'keep_first_returns', 'keep_last_returns']
# DESCRIPTION:
#             (default=False) If 'returns', drop observations where workers leave a firm then return to it; if 'returners', drop workers who ever leave then return to a firm; if 'keep_first_returns', keep first spell where a worker leaves a firm then returns to it; if 'keep_last_returns', keep last spell where a worker leaves a firm then returns to it; if False, keep all observations.
#
# KEY: 'drop_returns_to_stays'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) Applies only if 'drop_returns' is set to False. If True, when recollapsing collapsed data, drop observations that need to be recollapsed instead of collapsing (this is for computational efficiency when re-collapsing data for leave-one-out connected components, where intermediate observations can be dropped, causing a worker who returns to a firm to become a stayer).
#
# KEY: 'is_sorted'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If False, dataframe will be sorted by i (and t, if included). Returned dataframe will be sorted. Sorting may alter original dataframe if copy is set to False. Set is_sorted to True if dataframe is already sorted.
#
# KEY: 'copy'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If False, avoid copying data when possible.
#
# KEY: 'force'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If True, force all cleaning methods to run; much faster if set to False.
#
# KEY: 'verbose'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If True, print progress during data cleaning.
#
# ----- Simulation -----
# KEY: 'n_workers'
# CURRENT VALUE: 10000
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=10000) Number of workers.
#
# KEY: 'n_time'
# CURRENT VALUE: 5
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=5) Time length of panel.
#
# KEY: 'firm_size'
# CURRENT VALUE: 50
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '> 0'
# DESCRIPTION:
#             (default=50) Average observations per firm per time period.
#
# KEY: 'nk'
# CURRENT VALUE: 10
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=10) Number of firm types.
#
# KEY: 'nl'
# CURRENT VALUE: 5
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=5) Number of worker types.
#
# KEY: 'alpha_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of individual fixed effect (volatility of worker effects).
#
# KEY: 'psi_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of firm fixed effect (volatility of firm effects).
#
# KEY: 'w_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of residual in AKM wage equation (volatility of wage shocks).
#
# KEY: 'c_sort'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Sorting effect.
#
# KEY: 'c_netw'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Network effect.
#
# KEY: 'c_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of sorting/network effects.
#
# KEY: 'p_move'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: 'in [0, 1]'
# DESCRIPTION:
#             (default=0.5) Probability a worker moves firms in any period.

# %% [markdown]
# ## Second, set parameter choices

# %%
nl = 2 # Number of worker types
nk = 3 # Number of firm types
blm_params = tw.blm_params({
    'nl': nl,
    'nk': nk
})
cluster_params = bpd.cluster_params({
    'measures': bpd.measures.CDFs(),
    'grouping': bpd.grouping.KMeans(n_clusters=nk),
    'is_sorted': True,
    'copy': False
})
clean_params = bpd.clean_params({
    'drop_returns': 'returners',
    'copy': False
})
sim_params = bpd.sim_params({
    'nl': nl,
    'nk': nk,
    'c_sort': 0,
    'c_netw': 0,
    'c_sig': 1
})

# %% [markdown]
# ## Simulate data
#
# Simulate a bipartite network using BipartitePandas. We use this here to demonstrate how to fit the estimator using real data.
#
# Note that `l` gives the true worker type and `k` gives the true firm type, while `alpha` gives the true worker effect and `psi` gives the true firm effect.
#
# The BLM estimator uses the firm types computed via clustering, which are saved in columns `g1` and `g2`.

# %%
sim_data = bpd.BipartiteDataFrame(bpd.SimBipartite(sim_params).simulate()[['i', 'j', 'y', 't', 'l', 'alpha', 'k', 'psi']]).clean(clean_params).cluster(cluster_params).collapse(is_sorted=True, copy=False).to_eventstudy(is_sorted=True, copy=False)
print('Movers data')
display(sim_data[sim_data['m'] > 0])
print('Stayers data')
display(sim_data[sim_data['m'] == 0])
# Out:
# checking required columns and datatypes
# sorting rows
# dropping NaN observations
# generating 'm' column
# keeping highest paying job for i-t (worker-year) duplicates (how='max')
# dropping workers who leave a firm then return to it (how='returners')
# making 'i' ids contiguous
# making 'j' ids contiguous
# computing largest connected set (how=None)
# sorting columns
# resetting index
# Movers data
#           i   j1   j2        y1        y2  t11  t12  t21  t22  g1  ...  w2  m  \
# 0         0  146  123  0.531774 -1.400982    0    1    2    2   1  ...   1  1
# 1         0  123  177 -1.400982 -1.230670    2    2    3    3   2  ...   1  1
# 2         0  177   96 -1.230670  0.120878    3    3    4    4   1  ...   1  1
# 3         1  102   37  1.106482  0.385908    0    0    1    2   2  ...   2  1
# 4         1   37   22  0.385908 -0.951128    1    2    3    4   0  ...   2  1
# ...     ...  ...  ...       ...       ...  ...  ...  ...  ...  ..  ...  .. ..
# 20293  9915  178  110 -0.078981  0.443435    1    1    2    2   1  ...   1  1
# 20294  9915  110   49  0.443435 -0.079539    2    2    3    4   2  ...   2  1
# 20295  9916  147  164  0.569279  1.118145    0    0    1    1   1  ...   1  1
# 20296  9916  164  146  1.118145  0.606734    1    1    2    2   1  ...   1  1
# 20297  9916  146   62  0.606734 -1.191613    2    2    3    4   1  ...   2  1
#
#          alpha1    alpha2   k1   k2   l1   l2     psi1     psi2
# 0     -0.430727 -0.430727  2.0  1.0  0.0  0.0  0.67449  0.00000
# 1     -0.430727 -0.430727  1.0  2.0  0.0  0.0  0.00000  0.67449
# 2     -0.430727 -0.430727  2.0  1.0  0.0  0.0  0.67449  0.00000
# 3      0.430727  0.430727  1.0  0.0  1.0  1.0  0.00000 -0.67449
# 4      0.430727  0.430727  0.0  0.0  1.0  1.0 -0.67449 -0.67449
# ...         ...       ...  ...  ...  ...  ...      ...      ...
# 20293  0.430727  0.430727  2.0  1.0  1.0  1.0  0.67449  0.00000
# 20294  0.430727  0.430727  1.0  0.0  1.0  1.0  0.00000 -0.67449
# 20295 -0.430727 -0.430727  2.0  2.0  0.0  0.0  0.67449  0.67449
# 20296 -0.430727 -0.430727  2.0  2.0  0.0  0.0  0.67449  0.67449
# 20297 -0.430727 -0.430727  2.0  1.0  0.0  0.0  0.67449  0.00000
#
# [19650 rows x 22 columns]
# Stayers data
#           i   j1   j2        y1        y2  t11  t12  t21  t22  g1  ...  w2  m  \
# 10        4  153  153  1.400850  1.400850    0    4    0    4   1  ...   5  0
# 28       14  108  108 -0.220768 -0.220768    0    4    0    4   2  ...   5  0
# 29       15  161  161 -0.220857 -0.220857    0    4    0    4   1  ...   5  0
# 77       37   64   64 -0.610087 -0.610087    0    4    0    4   2  ...   5  0
# 102      51  173  173  1.268857  1.268857    0    4    0    4   1  ...   5  0
# ...     ...  ...  ...       ...       ...  ...  ...  ...  ...  ..  ...  .. ..
# 20135  9841   78   78  0.933407  0.933407    0    4    0    4   2  ...   5  0
# 20166  9855   68   68  0.222460  0.222460    0    4    0    4   2  ...   5  0
# 20176  9860   40   40 -0.551588 -0.551588    0    4    0    4   0  ...   5  0
# 20197  9870   10   10 -0.011855 -0.011855    0    4    0    4   0  ...   5  0
# 20244  9892  114  114  0.467899  0.467899    0    4    0    4   2  ...   5  0
#
#          alpha1    alpha2   k1   k2   l1   l2     psi1     psi2
# 10     0.430727  0.430727  2.0  2.0  1.0  1.0  0.67449  0.67449
# 28     0.430727  0.430727  1.0  1.0  1.0  1.0  0.00000  0.00000
# 29    -0.430727 -0.430727  2.0  2.0  0.0  0.0  0.67449  0.67449
# 77    -0.430727 -0.430727  1.0  1.0  0.0  0.0  0.00000  0.00000
# 102    0.430727  0.430727  2.0  2.0  1.0  1.0  0.67449  0.67449
# ...         ...       ...  ...  ...  ...  ...      ...      ...
# 20135  0.430727  0.430727  1.0  1.0  1.0  1.0  0.00000  0.00000
# 20166 -0.430727 -0.430727  1.0  1.0  0.0  0.0  0.00000  0.00000
# 20176  0.430727  0.430727  0.0  0.0  1.0  1.0 -0.67449 -0.67449
# 20197  0.430727  0.430727  0.0  0.0  1.0  1.0 -0.67449 -0.67449
# 20244  0.430727  0.430727  1.0  1.0  1.0  1.0  0.00000  0.00000
#
# [648 rows x 22 columns]

# %% [markdown]
# ## Initialize and run BLMEstimator
#
# <div class="alert alert-info">
#
# Note
#
# The `BLMEstimator` class requires data to be formatted as a BipartitePandas DataFrame.
#
# </div>

# %%
# Initialize BLM estimator
blm_fit = tw.BLMEstimator(blm_params)
# Fit BLM estimator
blm_fit.fit(jdata=sim_data[sim_data['m'] > 0], sdata=sim_data[sim_data['m'] == 0], n_init=40, n_best=5, ncore=4)
# Sort estimated parameters
blm_fit.model._sort_matrices(firm_effects=True)
# Out:
# 100%|███████████████████████████████████████████| 40/40 [00:21<00:00,  1.86it/s]

# %% [markdown]
# ## Check that log-likelihoods are monotonic

# %%
liks1 = blm_fit.model.liks1

print('Log-likelihoods monotonic (movers):', np.min(np.diff(liks1)) >= 0)

x_axis = range(1, len(liks1))
plt.plot(x_axis, np.diff(liks1), '.', label='liks1', color='red')
plt.plot(x_axis, np.zeros(len(liks1) - 1))
plt.xlabel('Iteration')
plt.ylabel('Change in log-likelihood')
# Out:
# Log-likelihoods monotonic (movers): True
# Text(0, 0.5, 'Change in log-likelihood')

# %%
liks0 = blm_fit.model.liks0

print('Log-likelihoods monotonic (stayers):', np.min(np.diff(liks0)) >= 0)

x_axis = range(1, len(liks0))
plt.plot(x_axis, np.diff(liks0), '.', label='liks0', color='red')
plt.plot(x_axis, np.zeros(len(liks0) - 1))
plt.xlabel('Iteration')
plt.ylabel('Change in log-likelihood')
# Out:
# Log-likelihoods monotonic (stayers): True
# Text(0, 0.5, 'Change in log-likelihood')

# %% [markdown]
# ## Now we can investigate the results

# %%
# Plot likelihood vs. connectedness
blm_fit.plot_liks_connectedness()

# %%
blm_fit.plot_A1()

# %% [markdown]
# ## Finally, we can compare estimates to the truth

# %%
# Compute true parameters
true_A1 = np.expand_dims(sim_data.groupby('l1')['alpha1'].mean().to_numpy(), 1) + np.tile(sim_data.groupby('k1')['psi1'].mean().to_numpy(), (nl, 1))
true_A2 = np.expand_dims(sim_data.groupby('l2')['alpha2'].mean().to_numpy(), 1) + np.tile(sim_data.groupby('k2')['psi2'].mean().to_numpy(), (nl, 1))

# %%
plt.plot(true_A1.flatten(), blm_fit.model.A1.flatten(), '.', label='A1', color='red')
plt.plot(true_A2.flatten(), blm_fit.model.A2.flatten(), '.', label='A2', color='green')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

# %% [markdown]
# # Control variables
#
# ## Simulating data with controls
#
# The package contains functions to simulate data from the BLM dgp. We use this here to see how to use control variables.
#
# In this example, we simulate a categorical, non-stationary, non-worker-type-interaction control variable. We use a low variance to ensure stability of the estimator.
#
# ## Check out simulation parameter options

# %%
print('----- Categorical -----')
tw.sim_categorical_control_params().describe_all()
print('----- Continuous -----')
tw.sim_continuous_control_params().describe_all()
# Out:
# ----- Categorical -----
# KEY: 'n'
# CURRENT VALUE: 6
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 2'
# DESCRIPTION:
#             (default=6) Number of types for the parameter.
#
# KEY: 'a1_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of simulated A1_cat (mean of fixed effects in first period).
#
# KEY: 'a1_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of simulated A1_cat (mean of fixed effects in first period).
#
# KEY: 'a2_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of simulated A2_cat (mean of fixed effects in second period).
#
# KEY: 'a2_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of simulated A2_cat (mean of fixed effects in second period).
#
# KEY: 's1_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of simulated S1_cat (standard deviation of fixed effects in first period).
#
# KEY: 's1_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of simulated S1_cat (standard deviation of fixed effects in first period).
#
# KEY: 's2_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of simulated S2_cat (standard deviation of fixed effects in second period).
#
# KEY: 's2_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of simulated S2_cat (standard deviation of fixed effects in second period).
#
# KEY: 'stationary_A'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, A1_cat and A2_cat must be equal.
#
# KEY: 'stationary_S'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, S1_cat and S2_cat must be equal.
#
# KEY: 'stationary_firm_type_variation'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, set constraints for A1_cat and A2_cat so that the firm type induced variation of worker-firm pair effects is the same in all periods. In particular, this sets A2_cat = np.mean(A2_cat, axis=1) + A1_cat - np.mean(A1_cat, axis=1).
#
# KEY: 'worker_type_interaction'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, effect can differ by worker type.
#
# ----- Continuous -----
# KEY: 'a1_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of simulated A1_cts (mean of coefficient in first period).
#
# KEY: 'a1_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of simulated A1_cts (mean of coefficient in first period).
#
# KEY: 'a2_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of simulated A2_cts (mean of coefficient in second period).
#
# KEY: 'a2_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of simulated A2_cts (mean of coefficient in second period).
#
# KEY: 's1_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of simulated S1_cts (standard deviation of coefficient in first period).
#
# KEY: 's1_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of simulated S1_cts (standard deviation of coefficient in first period).
#
# KEY: 's2_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of simulated S2_cts (standard deviation of coefficient in second period).
#
# KEY: 's2_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of simulated S2_cts (standard deviation of coefficient in second period).
#
# KEY: 'stationary_A'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, A1_cts and A2_cts must be equal.
#
# KEY: 'stationary_S'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, S1_cts and S2_cts must be equal.
#
# KEY: 'stationary_firm_type_variation'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, set constraints for A1_cts and A2_cts so that the firm type induced variation of worker-firm pair effects is the same in all periods. In particular, this sets A2_cts = np.mean(A2_cts) + A1_cts - np.mean(A1_cts).
#
# KEY: 'worker_type_interaction'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, effect can differ by worker type.

# %% [markdown]
# ## Set simulation parameter choices

# %%
n_control = 2 # Number of types for control variable

sim_cat_params = tw.sim_categorical_control_params({
    'n': n_control,
    'stationary_A': False, 'stationary_S': False,
    'worker_type_interaction': False,
    'a1_mu': -0.5, 'a1_sig': 0.25, 'a2_mu': 0.5, 'a2_sig': 0.25,
    's1_low': 0, 's1_high': 0.01, 's2_low': 0, 's2_high': 0.01
})
sim_cts_params = tw.sim_continuous_control_params({
    'stationary_A': True, 'stationary_S': True,
    'worker_type_interaction': True,
    'a1_mu': -0.15, 'a1_sig': 0.05, 'a2_mu': 0.15, 'a2_sig': 0.05,
    's1_low': 0, 's1_high': 0.01, 's2_low': 0, 's2_high': 0.01
})
blm_sim_params = tw.sim_params({
    'nl': nl,
    'nk': nk,
    'a1_mu': -2, 'a1_sig': 0.25, 'a2_mu': 2, 'a2_sig': 0.25,
    's1_low': 0, 's1_high': 0.01, 's2_low': 0, 's2_high': 0.01,
    'categorical_controls': {'cat_control': sim_cat_params},
    'continuous_controls': {'cts_control': sim_cts_params}
})

# %% [markdown]
# ## Estimating control variables
#
# PyTwoWay allows for categorical and continuous control variables.
#
# ### Categorical
#
# To define a categorical control variable, construct an instance of the parameter dictionary `tw.categorical_control_params()`.
#
# Then, inside an instance of `blm_params()`, link the key `'categorical_controls'` to a dictionary linking column names to their associated parameter dictionaries.
#
# ### Continuous
#
# To define a continuous control variable, construct an instance of the parameter dictionary `tw.continuous_control_params()`.
#
# Then, inside an instance of `blm_params()`, link the key `'continuous_controls'` to a dictionary linking column names to their associated parameter dictionaries.
#
# ### Constraints
#
# Constraints can be specified for control variables. They are set through the `cons_a` and `cons_s` keys for a given control variable's parameter dictionary, except for `NoWorkerTypeInteraction()`. Constraint options are:
# - `Linear()` - for a fixed firm type, worker types effects must change linearly
# - `Monotonic()` - for a fixed firm type, worker types effects must increase (or decrease) monotonically
# - `NoWorkerTypeInteraction()` - for a fixed firm type, worker types effects must all be the same
# - `Stationary()` - worker-firm pair effects are the same in all periods
# - `StationaryFirmTypeVariation()` - firm type induced variation of worker-firm pair effects is the same in all periods. In particular, this is equivalent to setting A2 = (np.mean(A2, axis=1) + A1.T - np.mean(A1, axis=1)).T.
# - `BoundedBelow()` - worker-firm pair effects are bounded below
# - `BoundedAbove()` - worker-firm pair effects are bounded above
#
# `NoWorkerTypeInteraction()` is not specified through the `cons_a` and `cons_s` keys. Instead, if you want a control variable to interact with the unobserved worker types, this can be specified by setting `worker_type_interaction=True` in the control variable's parameter dictionary.
#
# ## Check out estimation parameter options

# %%
print('----- Categorical -----')
tw.categorical_control_params().describe_all()
print('----- Continuous -----')
tw.continuous_control_params().describe_all()
# Out:
# ----- Categorical -----
# KEY: 'n'
# CURRENT VALUE: None
# VALID VALUES: None or one of type <class 'int'>
# CONSTRAINTS: '>= 2'
# DESCRIPTION:
#             (default=6) Number of types for the parameter. None will raise an error when running the estimator.
#
# KEY: 'a1_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of starting values for A1_cat (mean of fixed effects in first period).
#
# KEY: 'a1_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of starting values for A1_cat (mean of fixed effects in first period).
#
# KEY: 'a2_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of starting values for A2_cat (mean of fixed effects in second period).
#
# KEY: 'a2_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of starting values for A2_cat (mean of fixed effects in second period).
#
# KEY: 's1_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of starting values for S1_cat (standard deviation of fixed effects in first period).
#
# KEY: 's1_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of starting values for S1_cat (standard deviation of fixed effects in first period).
#
# KEY: 's2_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of starting values for S2_cat (standard deviation of fixed effects in second period).
#
# KEY: 's2_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of starting values for S2_cat (standard deviation of fixed effects in second period).
#
# KEY: 'worker_type_interaction'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, effect can differ by worker type.
#
# KEY: 'cons_a'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on A1 and A2. None is equivalent to [].
#
# KEY: 'cons_s'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on S1 and S2. None is equivalent to [].
#
# ----- Continuous -----
# KEY: 'a1_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of starting values for A1_cts (mean of coefficient in first period).
#
# KEY: 'a1_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of starting values for A1_cts (mean of coefficient in first period).
#
# KEY: 'a2_mu'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Mean of starting values for A2_cts (mean of coefficient in second period).
#
# KEY: 'a2_sig'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Standard error of starting values for A2_cts (mean of coefficient in second period).
#
# KEY: 's1_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of starting values for S1_cts (standard deviation of coefficient in first period).
#
# KEY: 's1_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of starting values for S1_cts (standard deviation of coefficient in first period).
#
# KEY: 's2_low'
# CURRENT VALUE: 0.3
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.3) Minimum value of starting values for S2_cts (standard deviation of coefficient in second period).
#
# KEY: 's2_high'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=0.5) Maximum value of starting values for S2_cts (standard deviation of coefficient in second period).
#
# KEY: 'worker_type_interaction'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, effect can differ by worker type.
#
# KEY: 'cons_a'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on A1 and A2. None is equivalent to [].
#
# KEY: 'cons_s'
# CURRENT VALUE: None
# VALID VALUES: None or one of or list of type (<class 'pytwoway.constraints.constraints.Linear'>, <class 'pytwoway.constraints.constraints.Monotonic'>, <class 'pytwoway.constraints.constraints.Stationary'>, <class 'pytwoway.constraints.constraints.StationaryFirmTypeVariation'>, <class 'pytwoway.constraints.constraints.BoundedBelow'>, <class 'pytwoway.constraints.constraints.BoundedAbove'>)
# DESCRIPTION:
#             (default=None) Constraint object or list of constraint objects with class method .get_constraints() that defines constraints on S1 and S2. None is equivalent to [].

# %% [markdown]
# ## Set estimation parameter choices

# %%
cat_params = tw.categorical_control_params({
    'n': n_control,
    'worker_type_interaction': False,
    'cons_a': None, 'cons_s': None,
    'a1_mu': -0.5, 'a1_sig': 0.25, 'a2_mu': 0.5, 'a2_sig': 0.25,
    's1_low': 0, 's1_high': 0.01, 's2_low': 0, 's2_high': 0.01
})
cts_params = tw.continuous_control_params({
    'worker_type_interaction': True,
    'cons_a': cons.Stationary(), 'cons_s': cons.Stationary(),
    'a1_mu': -0.15, 'a1_sig': 0.05, 'a2_mu': 0.15, 'a2_sig': 0.05,
    's1_low': 0, 's1_high': 0.01, 's2_low': 0, 's2_high': 0.01
})
blm_params = tw.blm_params({
    'nl': nl,
    'nk': nk,
    'a1_mu': -2, 'a1_sig': 0.25, 'a2_mu': 2, 'a2_sig': 0.25,
    's1_low': 0, 's1_high': 0.01, 's2_low': 0, 's2_high': 0.01,
    'categorical_controls': {'cat_control': cat_params},
    'continuous_controls': {'cts_control': cts_params}
})

# %% [markdown]
# ## Simulate data
#
# `sim_data` gives a dictionary where the key `'jdata'` gives simulated mover data and the key `'sdata'` gives simulated stayer data.
#
# `sim_params` gives a dictionary that links each type of control variable to the simulated parameter values for that type.

# %%
blm_true = tw.SimBLM(blm_sim_params)
sim_data, sim_params = blm_true.simulate(return_parameters=True)
sim_data['jdata'] = bpd.BipartiteDataFrame(i=np.arange(len(sim_data['jdata'])), **sim_data['jdata'])
sim_data['sdata'] = bpd.BipartiteDataFrame(i=len(sim_data['jdata']) + np.arange(len(sim_data['sdata'])), **sim_data['sdata'])

# %%
print('Movers data')
display(sim_data['jdata'])
print('Stayers data')
display(sim_data['sdata'])
print('Simulated parameter values')
display(sim_params)
# Out:
# Movers data
#      i  j1  j2        y1        y2  g1  g2  cat_control1  cat_control2  \
# 0    0   0   1 -2.347590  2.833606   0   0             1             1
# 1    1   0   1 -2.733870  2.323134   0   0             1             0
# 2    2   1   0 -2.540213  2.366053   0   0             1             1
# 3    3   1   0 -2.057172  2.725159   0   0             0             1
# 4    4   1   0 -2.078456  2.355190   0   0             0             0
# ..  ..  ..  ..       ...       ...  ..  ..           ...           ...
# 85  85   4   5 -2.770768  2.311687   2   2             1             0
# 86  86   5   4 -2.339342  2.594205   2   2             1             1
# 87  87   5   4 -2.933267  2.383301   2   2             0             1
# 88  88   5   4 -1.897855  2.226991   2   2             0             1
# 89  89   5   4 -2.694293  2.678816   2   2             1             1
#
#     cts_control1  cts_control2  l
# 0      -0.012400     -1.480711  1
# 1       1.426674     -0.364753  1
# 2       0.650224      0.367953  1
# 3      -1.172590     -1.019971  1
# 4      -1.050269     -0.470633  1
# ..           ...           ... ..
# 85      1.251258      0.832128  0
# 86     -0.868852      0.454074  0
# 87      2.179185      1.522026  0
# 88     -0.690603     -0.076602  1
# 89      0.876213      0.036865  0
#
# [90 rows x 12 columns]
# Stayers data
#       i  j1  j2        y1        y2  g1  g2  cat_control1  cat_control2  \
# 0    90   1   1 -2.735568  2.226976   0   0             0             1
# 1    91   0   0 -2.639889  2.292971   0   0             1             0
# 2    92   1   1 -2.893819  2.485565   0   0             1             1
# 3    93   0   0 -2.569019  1.884594   0   0             0             0
# 4    94   0   0 -2.874140  2.605265   0   0             0             1
# 5    95   1   1 -2.878931  1.751131   0   0             0             0
# 6    96   0   0 -2.177023  2.294151   0   0             0             0
# 7    97   1   1 -2.655755  2.430819   0   0             0             1
# 8    98   1   1 -2.465969  2.338449   0   0             0             0
# 9    99   0   0 -2.732422  2.388838   0   0             0             1
# 10  100   2   2 -2.289882  2.847072   1   1             0             1
# 11  101   2   2 -2.282112  2.054455   1   1             0             1
# 12  102   3   3 -2.804036  2.363601   1   1             1             1
# 13  103   2   2 -2.613037  2.445445   1   1             1             1
# 14  104   3   3 -1.848805  2.551664   1   1             0             0
# 15  105   3   3 -3.059330  1.984952   1   1             0             0
# 16  106   2   2 -2.566346  2.677053   1   1             0             1
# 17  107   3   3 -2.464779  2.571474   1   1             0             1
# 18  108   2   2 -2.013122  2.479102   1   1             1             0
# 19  109   3   3 -2.360005  1.868785   1   1             1             1
# 20  110   5   5 -2.135297  2.383857   2   2             1             1
# 21  111   5   5 -2.176499  1.564743   2   2             0             0
# 22  112   5   5 -2.007785  1.910218   2   2             0             0
# 23  113   4   4 -1.818043  2.048305   2   2             0             0
# 24  114   5   5 -2.572336  2.299528   2   2             0             0
# 25  115   4   4 -2.116825  2.346410   2   2             0             1
# 26  116   4   4 -2.222455  2.161893   2   2             0             1
# 27  117   5   5 -1.915262  2.686243   2   2             0             0
# 28  118   5   5 -1.885185  1.851181   2   2             0             0
# 29  119   5   5 -2.217679  2.363483   2   2             1             0
#
#     cts_control1  cts_control2  l
# 0      -0.163869      0.915552  0
# 1      -0.749141     -0.516078  0
# 2       0.424067     -0.389721  0
# 3      -1.049177      1.416462  0
# 4       0.474209     -0.991089  0
# 5       0.395219      2.070497  0
# 6      -0.710965     -0.219671  1
# 7      -0.597680     -0.087557  0
# 8      -1.592324     -0.748919  0
# 9      -0.258734      0.018789  0
# 10     -0.302006     -1.658351  1
# 11     -0.273745      1.455937  1
# 12      1.631507      0.228779  1
# 13      0.825033     -0.089565  1
# 14     -2.028917     -1.374538  1
# 15      2.717008      0.818771  1
# 16      0.731837     -1.004984  1
# 17      0.357432     -0.639663  1
# 18     -1.441391     -1.235316  1
# 19     -0.181130      2.078446  0
# 20      0.109582     -0.659585  1
# 21      0.436851      1.597022  1
# 22     -0.295369      0.287530  1
# 23     -1.023459     -0.293767  1
# 24      0.450347      0.790060  0
# 25      0.026996     -0.530671  1
# 26      0.508921      0.201003  1
# 27     -0.623964     -2.736793  1
# 28     -0.809655      0.542515  1
# 29      0.435964     -1.551091  1
# Simulated parameter values
# {'A1': array([[-2.40744893, -2.00356623, -2.12320652],
#         [-1.98245245, -1.99464976, -1.71374711]]),
#  'A2': array([[1.91924489, 1.79697177, 2.20310877],
#         [1.97467431, 1.93444206, 1.72795495]]),
#  'S1': array([[0.00463476, 0.00334212, 0.00714201],
#         [0.00650464, 0.00750162, 0.00331783]]),
#  'S2': array([[0.00649323, 0.00132294, 0.0098915 ],
#         [0.00070515, 0.00843532, 0.00300054]]),
#  'pk1': array([[0.16584964, 0.83415036],
#         [0.73535091, 0.26464909],
#         [0.61166652, 0.38833348],
#         [0.73951866, 0.26048134],
#         [0.74334437, 0.25665563],
#         [0.64978441, 0.35021559],
#         [0.75957853, 0.24042147],
#         [0.78927861, 0.21072139],
#         [0.97340758, 0.02659242]]),
#  'pk0': array([[0.82244817, 0.17755183],
#         [0.13022042, 0.86977958],
#         [0.16390722, 0.83609278]]),
#  'A1_cat': {'cat_control': array([-0.37098543, -0.38798229])},
#  'A2_cat': {'cat_control': array([0.25649156, 0.48672615])},
#  'S1_cat': {'cat_control': array([0.00921876, 0.00243858])},
#  'S2_cat': {'cat_control': array([0.00959308, 0.00438104])},
#  'A1_cts': {'cts_control': array([-0.20045333, -0.25455905])},
#  'A2_cts': {'cts_control': array([-0.20045333, -0.25455905])},
#  'S1_cts': {'cts_control': array([0.00382749, 0.00989126])},
#  'S2_cts': {'cts_control': array([0.00382749, 0.00989126])}}

# %% [markdown]
# ## Initialize and run BLMEstimator

# %%
# Initialize BLM estimator
blm_fit = tw.BLMEstimator(blm_params)
# Fit BLM estimator
blm_fit.fit(jdata=sim_data['jdata'], sdata=sim_data['sdata'], n_init=80, n_best=5, ncore=4)
# Sort estimated parameters
blm_fit.model._sort_matrices()
# Out:
# 100%|███████████████████████████████████████████| 80/80 [00:25<00:00,  3.12it/s]

# %% [markdown]
# ## Check that log-likelihoods are monotonic

# %%
liks1 = blm_fit.model.liks1

print('Log-likelihoods monotonic (movers):', np.min(np.diff(liks1)) >= 0)

x_axis = range(1, len(liks1))
plt.plot(x_axis, np.diff(liks1), '.', label='liks1', color='red')
plt.plot(x_axis, np.zeros(len(liks1) - 1))
plt.xlabel('Iteration')
plt.ylabel('Change in log-likelihood')
# Out:
# Log-likelihoods monotonic (movers): False
# Text(0, 0.5, 'Change in log-likelihood')

# %%
liks0 = blm_fit.model.liks0

print('Log-likelihoods monotonic (stayers):', np.min(np.diff(liks0)) >= 0)

x_axis = range(1, len(liks0))
plt.plot(x_axis, np.diff(liks0), '.', label='liks0', color='red')
plt.plot(x_axis, np.zeros(len(liks0) - 1))
plt.xlabel('Iteration')
plt.ylabel('Change in log-likelihood')
# Out:
# Log-likelihoods monotonic (stayers): True
# Text(0, 0.5, 'Change in log-likelihood')

# %% [markdown]
# ## Now we can investigate the results

# %%
# Plot likelihood vs. connectedness
blm_fit.plot_liks_connectedness()

# %%
blm_fit.plot_A1()

# %% [markdown]
# ## Finally, we can compare estimates to the truth

# %%
plt.plot(sim_params['A1'].flatten(), blm_fit.model.A1.flatten(), '.', label='A1', color='red')
plt.plot(sim_params['A2'].flatten(), blm_fit.model.A2.flatten(), '.', label='A2', color='green')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(sim_params['S1'].flatten(), blm_fit.model.S1.flatten(), '.', label='S1', color='red')
plt.plot(sim_params['S2'].flatten(), blm_fit.model.S2.flatten(), '.', label='S2', color='green')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(sim_params['A1_cat']['cat_control'].flatten(), blm_fit.model.A1_cat['cat_control'].flatten(), '.', label='A1_cat', color='red')
plt.plot(sim_params['A2_cat']['cat_control'].flatten(), blm_fit.model.A2_cat['cat_control'].flatten(), '.', label='A2_cat', color='green')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(sim_params['S1_cat']['cat_control'].flatten(), blm_fit.model.S1_cat['cat_control'].flatten(), '.', label='S1_cat', color='red')
plt.plot(sim_params['S2_cat']['cat_control'].flatten(), blm_fit.model.S2_cat['cat_control'].flatten(), '.', label='S2_cat', color='green')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(sim_params['A1_cts']['cts_control'].flatten(), blm_fit.model.A1_cts['cts_control'].flatten(), '.', label='A1_cts', color='red')
plt.plot(sim_params['A2_cts']['cts_control'].flatten(), blm_fit.model.A2_cts['cts_control'].flatten(), '.', label='A2_cts', color='green')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(sim_params['S1_cts']['cts_control'].flatten(), blm_fit.model.S1_cts['cts_control'].flatten(), '.', label='S1_cts', color='red')
plt.plot(sim_params['S2_cts']['cts_control'].flatten(), blm_fit.model.S2_cts['cts_control'].flatten(), '.', label='S2_cts', color='green')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(sim_params['pk1'].flatten(), blm_fit.model.pk1.flatten(), '.', label='pk1', color='red')
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

# %% [markdown]
# The parameters are identified only up to a constant intercept. If we take the sum over the estimators we see the model performs well.

# %%
## A1 and A2 ##
plt.plot(
    (sim_params['A1'] + sim_params['A1_cat']['cat_control'][0]).flatten(),
    (blm_fit.model.A1 + blm_fit.model.A1_cat['cat_control'][0]).flatten(),
    '.', label='A1 + A1_cat[0]', color='red'
)
plt.plot(
    (sim_params['A1'] + sim_params['A1_cat']['cat_control'][1]).flatten(),
    (blm_fit.model.A1 + blm_fit.model.A1_cat['cat_control'][1]).flatten(),
    '.', label='A1 + A1_cat[1]', color='green'
)
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(
    (sim_params['A2'] + sim_params['A2_cat']['cat_control'][0]).flatten(),
    (blm_fit.model.A2 + blm_fit.model.A2_cat['cat_control'][0]).flatten(),
    '.', label='A2 + A2_cat[0]', color='red'
)
plt.plot(
    (sim_params['A2'] + sim_params['A2_cat']['cat_control'][1]).flatten(),
    (blm_fit.model.A2 + blm_fit.model.A2_cat['cat_control'][1]).flatten(),
    '.', label='A2 + A2_cat[1]', color='green'
)
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

## S1 and S2 ##
plt.plot(
    np.sqrt((sim_params['S1'] ** 2 + sim_params['S1_cat']['cat_control'][0] ** 2).flatten()),
    np.sqrt((blm_fit.model.S1 ** 2 + blm_fit.model.S1_cat['cat_control'][0] ** 2).flatten()),
    '.', label='sqrt(S1^2 + S1_cat[0]^2)', color='red'
)
plt.plot(
    np.sqrt((sim_params['S1'] ** 2 + sim_params['S1_cat']['cat_control'][1] ** 2).flatten()),
    np.sqrt((blm_fit.model.S1 ** 2 + blm_fit.model.S1_cat['cat_control'][1] ** 2).flatten()),
    '.', label='sqrt(S1^2 + S1_cat[1]^2)', color='green'
)
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()

plt.plot(
    np.sqrt((sim_params['S2'] ** 2 + sim_params['S2_cat']['cat_control'][0] ** 2).flatten()),
    np.sqrt((blm_fit.model.S2 ** 2 + blm_fit.model.S2_cat['cat_control'][0] ** 2).flatten()),
    '.', label='sqrt(S2^2 + S2_cat[0]^2)', color='red'
)
plt.plot(
    np.sqrt((sim_params['S2'] ** 2 + sim_params['S2_cat']['cat_control'][1] ** 2).flatten()),
    np.sqrt((blm_fit.model.S2 ** 2 + blm_fit.model.S2_cat['cat_control'][1] ** 2).flatten()),
    '.', label='sqrt(S2^2 + S2_cat[1]^2)', color='green'
)
plt.xlabel('Truth')
plt.ylabel('Estimate')
plt.legend()
plt.show()
