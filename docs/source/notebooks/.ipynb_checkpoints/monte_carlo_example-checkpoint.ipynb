# %% [markdown]
# # Monte Carlo example

# %%
# Add PyTwoWay to system path, do not run this
import sys
sys.path.append('../../..')

# %%
# Import the PyTwoWay package
# (Make sure you have installed it using pip install pytwoway)
import pytwoway as tw
import bipartitepandas as bpd
import numpy as np

# %% [markdown]
# ## First, check out parameter options

# %%
print('----- Simulation -----')
bpd.sim_params().describe_all()
print('----- FE -----')
tw.fe_params().describe_all()
print('----- CRE -----')
tw.cre_params().describe_all()
print('----- Clustering -----')
bpd.cluster_params().describe_all()
print('----- Cleaning -----')
bpd.clean_params().describe_all()
# Out:
# ----- Simulation -----
# KEY: 'n_workers'
# CURRENT VALUE: 10000
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=10000) Number of workers.
#
# KEY: 'n_time'
# CURRENT VALUE: 5
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=5) Time length of panel.
#
# KEY: 'firm_size'
# CURRENT VALUE: 50
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '> 0'
# DESCRIPTION:
#             (default=50) Average observations per firm per time period.
#
# KEY: 'nk'
# CURRENT VALUE: 10
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=10) Number of firm types.
#
# KEY: 'nl'
# CURRENT VALUE: 5
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=5) Number of worker types.
#
# KEY: 'alpha_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of individual fixed effect (volatility of worker effects).
#
# KEY: 'psi_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of firm fixed effect (volatility of firm effects).
#
# KEY: 'w_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of residual in AKM wage equation (volatility of wage shocks).
#
# KEY: 'c_sort'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Sorting effect.
#
# KEY: 'c_netw'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# DESCRIPTION:
#             (default=1) Network effect.
#
# KEY: 'c_sig'
# CURRENT VALUE: 1
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: '>= 0'
# DESCRIPTION:
#             (default=1) Standard error of sorting/network effects.
#
# KEY: 'p_move'
# CURRENT VALUE: 0.5
# VALID VALUES: one of type (<class 'float'>, <class 'int'>)
# CONSTRAINTS: 'in [0, 1]'
# DESCRIPTION:
#             (default=0.5) Probability a worker moves firms in any period.
#
# ----- FE -----
# KEY: 'ncore'
# CURRENT VALUE: 1
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=1) Number of cores to use.
#
# KEY: 'weighted'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If True, use weighted estimators.
#
# KEY: 'statsonly'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, return only basic statistics.
#
# KEY: 'feonly'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, estimate only fixed effects and not variances.
#
# KEY: 'Q'
# CURRENT VALUE: 'cov(alpha, psi)'
# VALID VALUES: one of ['cov(alpha, psi)', 'cov(psi_t, psi_{t+1})']
# DESCRIPTION:
#             (default='cov(alpha, psi)') Which Q matrix to consider. Options include 'cov(alpha, psi)' and 'cov(psi_t, psi_{t+1})'.
#
# KEY: 'ndraw_trace'
# CURRENT VALUE: 5
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=5) Number of draws to use in trace approximations.
#
# KEY: 'he'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, estimate heteroskedastic correction.
#
# KEY: 'he_analytical'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, estimate heteroskedastic correction using analytical formula; if False, use JL approxmation.
#
# KEY: 'lev_batchsize'
# CURRENT VALUE: 50
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=50) Number of draws to use for each batch in approximation of leverages for heteroskedastic correction.
#
# KEY: 'lev_batchsize_multiprocessing'
# CURRENT VALUE: 10
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=10) Batch size to send in parallel. Should evenly divide 'lev_batchsize'.
#
# KEY: 'lev_nbatches'
# CURRENT VALUE: 5
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=5) Maximum number of batches to run in approximation of leverages for heteroskedastic correction.
#
# KEY: 'lev_threshold_obs'
# CURRENT VALUE: 100
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=100) Minimum number of observations with Pii >= threshold where batches will keep running in approximation of leverages for heteroskedastic correction. Once this threshold is met, remaining Pii above threshold will be recomputed analytically.
#
# KEY: 'lev_threshold_pii'
# CURRENT VALUE: 0.98
# VALID VALUES: one of type <class 'float'>
# CONSTRAINTS: 'in [0, 1]'
# DESCRIPTION:
#             (default=0.98) Threshold Pii value for computing threshold number of Pii observations in approximation of leverages for heteroskedastic correction.
#
# KEY: 'levfile'
# CURRENT VALUE: ''
# VALID VALUES: one of type <class 'str'>
# DESCRIPTION:
#             (default='') File to load precomputed leverages for heteroskedastic correction.
#
# KEY: 'out'
# CURRENT VALUE: 'res_fe.json'
# VALID VALUES: one of type <class 'str'>
# DESCRIPTION:
#             (default='res_fe.json') Outputfile where results are saved.
#
# ----- CRE -----
# KEY: 'ncore'
# CURRENT VALUE: 1
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=1) Number of cores to use.
#
# KEY: 'posterior'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, compute posterior variance.
#
# KEY: 'wo_btw'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, sets between variation to 0, pure RE.
#
# KEY: 'ndraw_trace'
# CURRENT VALUE: 5
# VALID VALUES: one of type <class 'int'>
# CONSTRAINTS: '>= 1'
# DESCRIPTION:
#             (default=5) Number of draws to use in trace approximations.
#
# KEY: 'out'
# CURRENT VALUE: 'res_cre.json'
# VALID VALUES: one of type <class 'str'>
# DESCRIPTION:
#             (default='res_fe.json') Outputfile where results are saved.
#
# ----- Clustering -----
# KEY: 'measures'
# CURRENT VALUE: <bipartitepandas.measures.measures.CDFs object at 0x7f8f20295130>
# VALID VALUES: one of or list of type (<class 'bipartitepandas.measures.measures.CDFs'>, <class 'bipartitepandas.measures.measures.Moments'>)
# DESCRIPTION:
#             (default=bpd.measures.CDFs()) How to compute measures for clustering. Options can be seen in bipartitepandas.measures.
#
# KEY: 'grouping'
# CURRENT VALUE: <bipartitepandas.grouping.grouping.KMeans object at 0x7f8f20295160>
# VALID VALUES: one of type (<class 'bipartitepandas.grouping.grouping.KMeans'>, <class 'bipartitepandas.grouping.grouping.Quantiles'>)
# DESCRIPTION:
#             (default=bpd.grouping.KMeans()) How to group firms based on measures. Options can be seen in bipartitepandas.grouping.
#
# KEY: 'stayers_movers'
# CURRENT VALUE: None
# VALID VALUES: one of [None, 'stayers', 'movers']
# DESCRIPTION:
#             (default=None) If None, clusters on entire dataset; if 'stayers', clusters on only stayers; if 'movers', clusters on only movers; if 'stays', clusters on only stays; if 'moves', clusters on only moves.
#
# KEY: 't'
# CURRENT VALUE: None
# VALID VALUES: None or one of type (<class 'int'>, <class 'list'>)
# DESCRIPTION:
#             (default=None) If None, clusters on entire dataset; if int, gives period in data to consider (only valid for non-collapsed data); if list of int, gives periods in data to consider (only valid for non-collapsed data).
#
# KEY: 'weighted'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If True, weight firm clusters by firm size (if a weight column is included, firm weight is computed using this column; otherwise, each observation is given weight 1).
#
# KEY: 'dropna'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If True, drop observations where firms aren't clustered; if False, keep all observations.
#
# KEY: 'clean_params'
# CURRENT VALUE: None
# VALID VALUES: None or one of type <class 'bipartitepandas.util.ParamsDict'>
# DESCRIPTION:
#             (default=None) Dictionary of parameters for cleaning. This is used when observations get dropped because they were not clustered. Default is None, which sets connectedness to be the connectedness measure previously used. Run bpd.clean_params().describe_all() for descriptions of all valid parameters.
#
# KEY: 'is_sorted'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) For event study format. If False, dataframe will be sorted by i (and t, if included). Returned dataframe is not guaranteed to be sorted if original dataframe is not sorted. Sorting may alter original dataframe if copy is set to False. Set is_sorted to True if dataframe is already sorted.
#
# KEY: 'copy'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If False, avoid copy.
#
# ----- Cleaning -----
# KEY: 'connectedness'
# CURRENT VALUE: None
# VALID VALUES: one of ['connected', 'leave_out_observation', 'leave_out_spell', 'leave_out_match', 'leave_out_worker', 'leave_out_firm', None]
# DESCRIPTION:
#             (default=None) When computing largest connected set of firms: if 'connected', keep observations in the largest connected set of firms; if 'leave_out_observation', keep observations in the largest leave-one-observation-out connected set; if 'leave_out_spell', keep observations in the largest leave-one-spell-out connected set; if 'leave_out_match', keep observations in the largest leave-one-match-out connected set; if 'leave_out_worker', keep observations in the largest leave-one-worker-out connected set; if 'leave_out_firm', keep observations in the largest leave-one-firm-out connected set; if None, keep all observations.
#
# KEY: 'component_size_variable'
# CURRENT VALUE: 'firms'
# VALID VALUES: one of ['len', 'length', 'firms', 'workers', 'stayers', 'movers', 'firms_plus_workers', 'firms_plus_stayers', 'firms_plus_movers', 'len_stayers', 'length_stayers', 'len_movers', 'length_movers', 'stays', 'moves']
# DESCRIPTION:
#         (default='firms') How to determine largest connected component. Options are 'len'/'length' (length of frames), 'firms' (number of unique firms), 'workers' (number of unique workers), 'stayers' (number of unique stayers), 'movers' (number of unique movers), 'firms_plus_workers' (number of unique firms + number of unique workers), 'firms_plus_stayers' (number of unique firms + number of unique stayers), 'firms_plus_movers' (number of unique firms + number of unique movers), 'len_stayers'/'length_stayers' (number of stayer observations), 'len_movers'/'length_movers' (number of mover observations), 'stays' (number of stay observations), and 'moves' (number of move observations).
#
# KEY: 'i_t_how'
# CURRENT VALUE: 'max'
# VALID VALUES: one of type (<class 'builtin_function_or_method'>, <class 'function'>, <class 'method'>, <class 'str'>)
# DESCRIPTION:
#             (default='max') When dropping i-t duplicates: if 'max', keep max paying job; otherwise, take `i_t_how` over duplicate worker-firm-year observations, then take the highest paying worker-firm observation. `i_t_how` can take any input valid for a Pandas transform. Note that if multiple time and/or firm columns are included (as in collapsed long and event study formats), then data is converted to long, cleaned, then converted back to its original format.
#
# KEY: 'drop_returns'
# CURRENT VALUE: False
# VALID VALUES: one of [False, 'returns', 'returners', 'keep_first_returns', 'keep_last_returns']
# DESCRIPTION:
#             (default=False) If 'returns', drop observations where workers leave a firm then return to it; if 'returners', drop workers who ever leave then return to a firm; if 'keep_first_returns', keep first spell where a worker leaves a firm then returns to it; if 'keep_last_returns', keep last spell where a worker leaves a firm then returns to it; if False, keep all observations.
#
# KEY: 'drop_returns_to_stays'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) Applies only if 'drop_returns' is set to False. If True, when recollapsing collapsed data, drop observations that need to be recollapsed instead of collapsing (this is for computational efficiency when re-collapsing data for leave-one-out connected components, where intermediate observations can be dropped, causing a worker who returns to a firm to become a stayer).
#
# KEY: 'is_sorted'
# CURRENT VALUE: False
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=False) If False, dataframe will be sorted by i (and t, if included). Returned dataframe will be sorted. Sorting may alter original dataframe if copy is set to False. Set is_sorted to True if dataframe is already sorted.
#
# KEY: 'copy'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If False, avoid copying data when possible.
#
# KEY: 'force'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If True, force all cleaning methods to run; much faster if set to False.
#
# KEY: 'verbose'
# CURRENT VALUE: True
# VALID VALUES: one of type <class 'bool'>
# DESCRIPTION:
#             (default=True) If True, print progress during data cleaning.

# %% [markdown]
# ## Second, set parameter choices

# %%
# Set parameters
sim_params = bpd.sim_params({'n_workers': 1000, 'firm_size': 5, 'alpha_sig': 2, 'w_sig': 2, 'c_sort': 1.5, 'c_netw': 1.5, 'p_move': 0.1})
fe_params = tw.fe_params({'he': True, 'lev_threshold_obs': 1, 'weighted': True})
cre_params = tw.cre_params()
cluster_params = bpd.cluster_params()
clean_params = bpd.clean_params({'verbose': False})

# %% [markdown]
# ## Third, run the Monte Carlo simulation using the parameter choices

# %%
# Create the TwoWayMonteCarlo object
twmc = tw.MonteCarlo(
    sim_params=sim_params,
    fe_params=fe_params,
    cre_params=cre_params,
    cluster_params=cluster_params,
    clean_params=clean_params,
    collapse=True, # If True, run estimators on data collapsed at the worker-firm spell level
    move_to_worker=False, # If True, each move is treated as a new worker
    log=False # If True, will create log file(s)
)
# Run the Monte Carlo estimation
twmc.monte_carlo(
    N=50, # Number of simulations
    ncore=1, # Number of cores to use
    rng=np.random.default_rng(1234) # NumPy random number generator. This overrides the random number generators for simulating, FE, and CRE.
)
# Out:
#   0%|                                                    | 0/50 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 85.98it/s]
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 70.71it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 31.86it/s]
#   2%|▉                                           | 1/50 [00:03<02:50,  3.48s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 211.03it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 212.60it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 121.55it/s]
#   4%|█▊                                          | 2/50 [00:04<01:51,  2.31s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 69.19it/s]
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 62.76it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 27.14it/s]
#   6%|██▋                                         | 3/50 [00:09<02:37,  3.35s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 264.01it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 254.81it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 4 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 128.91it/s]
#   8%|███▌                                        | 4/50 [00:10<01:57,  2.56s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 196.30it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 176.97it/s]
# ../../../pytwoway/fe.py:1123: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. There is/are 0 observation(s) with Pii above this threshold. These will be recomputed analytically. It took 5 batch(es) to get below the threshold of 1 bad observations.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 94.61it/s]
#  10%|████▍                                       | 5/50 [00:12<01:40,  2.23s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 201.05it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 181.33it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 96.87it/s]
#  12%|█████▎                                      | 6/50 [00:14<01:29,  2.02s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 193.19it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 190.64it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 95.89it/s]
#  14%|██████▏                                     | 7/50 [00:15<01:21,  1.89s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 149.01it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 133.36it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 73.09it/s]
#  16%|███████                                     | 8/50 [00:17<01:20,  1.92s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 99.01it/s]
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 91.36it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 50.59it/s]
#  18%|███████▉                                    | 9/50 [00:21<01:38,  2.41s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 206.15it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 185.23it/s]
# ../../../pytwoway/fe.py:1123: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. There is/are 0 observation(s) with Pii above this threshold. These will be recomputed analytically. It took 5 batch(es) to get below the threshold of 1 bad observations.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 100.72it/s]
#  20%|████████▌                                  | 10/50 [00:22<01:26,  2.17s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 192.83it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 187.64it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 93.17it/s]
#  22%|█████████▍                                 | 11/50 [00:24<01:18,  2.02s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 76.04it/s]
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 62.57it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 27.55it/s]
#  24%|██████████▎                                | 12/50 [00:28<01:40,  2.64s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 167.39it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 148.56it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 3 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 78.93it/s]
#  26%|███████████▏                               | 13/50 [00:30<01:30,  2.45s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 217.00it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 215.22it/s]
# ../../../pytwoway/fe.py:1123: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. There is/are 0 observation(s) with Pii above this threshold. These will be recomputed analytically. It took 4 batch(es) to get below the threshold of 1 bad observations.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 116.39it/s]
#  28%|████████████                               | 14/50 [00:31<01:14,  2.08s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 207.32it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 197.75it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 3 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 98.82it/s]
#  30%|████████████▉                              | 15/50 [00:33<01:07,  1.94s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 244.47it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 218.83it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 122.50it/s]
#  32%|█████████████▊                             | 16/50 [00:34<01:00,  1.77s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 109.89it/s]
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 95.69it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 50.40it/s]
#  34%|██████████████▌                            | 17/50 [00:37<01:07,  2.06s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 222.22it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 223.37it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 3 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 112.61it/s]
#  36%|███████████████▍                           | 18/50 [00:39<00:59,  1.87s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 199.60it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 186.51it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 94.20it/s]
#  38%|████████████████▎                          | 19/50 [00:40<00:55,  1.79s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 187.58it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 179.47it/s]
# ../../../pytwoway/fe.py:1123: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. There is/are 0 observation(s) with Pii above this threshold. These will be recomputed analytically. It took 5 batch(es) to get below the threshold of 1 bad observations.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 96.54it/s]
#  40%|█████████████████▏                         | 20/50 [00:42<00:52,  1.75s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 199.24it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 182.91it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 98.47it/s]
#  42%|██████████████████                         | 21/50 [00:43<00:49,  1.70s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 160.55it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 143.94it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 79.44it/s]
#  44%|██████████████████▉                        | 22/50 [00:45<00:49,  1.76s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 167.22it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 162.96it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 85.28it/s]
#  46%|███████████████████▊                       | 23/50 [00:47<00:47,  1.76s/it]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 87.68it/s]
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 77.00it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 41.00it/s]
#  48%|████████████████████▋                      | 24/50 [00:50<00:58,  2.24s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 141.22it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 128.17it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 66.43it/s]
#  50%|█████████████████████▌                     | 25/50 [00:52<00:54,  2.20s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 208.04it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 201.24it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 4 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 90.82it/s]
#  52%|██████████████████████▎                    | 26/50 [00:54<00:48,  2.01s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 226.60it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 216.83it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 116.15it/s]
#  54%|███████████████████████▏                   | 27/50 [00:55<00:42,  1.83s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 183.51it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 168.37it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 88.93it/s]
#  56%|████████████████████████                   | 28/50 [00:57<00:39,  1.80s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 247.97it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 251.26it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 3 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 131.90it/s]
#  58%|████████████████████████▉                  | 29/50 [00:58<00:34,  1.64s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 259.78it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 255.77it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 129.59it/s]
#  60%|█████████████████████████▊                 | 30/50 [01:00<00:30,  1.54s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 193.92it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 180.62it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 95.20it/s]
#  62%|██████████████████████████▋                | 31/50 [01:01<00:29,  1.56s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 247.16it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 257.51it/s]
# ../../../pytwoway/fe.py:1123: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. There is/are 0 observation(s) with Pii above this threshold. These will be recomputed analytically. It took 5 batch(es) to get below the threshold of 1 bad observations.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 131.41it/s]
#  64%|███████████████████████████▌               | 32/50 [01:03<00:26,  1.47s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 253.92it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 253.52it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 135.51it/s]
#  66%|████████████████████████████▍              | 33/50 [01:04<00:24,  1.41s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 275.12it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 277.62it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 134.26it/s]
#  68%|█████████████████████████████▏             | 34/50 [01:05<00:21,  1.35s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 248.46it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 263.83it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 129.59it/s]
#  70%|██████████████████████████████             | 35/50 [01:06<00:19,  1.32s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 244.81it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 251.83it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 128.18it/s]
#  72%|██████████████████████████████▉            | 36/50 [01:08<00:18,  1.31s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 219.01it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 226.07it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 114.71it/s]
#  74%|███████████████████████████████▊           | 37/50 [01:09<00:17,  1.33s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 119.92it/s]
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 99.25it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 4 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 55.94it/s]
#  76%|████████████████████████████████▋          | 38/50 [01:12<00:20,  1.70s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 219.99it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 193.30it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 106.26it/s]
#  78%|█████████████████████████████████▌         | 39/50 [01:13<00:17,  1.63s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 131.95it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 116.37it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 64.43it/s]
#  80%|██████████████████████████████████▍        | 40/50 [01:15<00:18,  1.81s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 263.46it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 253.25it/s]
# ../../../pytwoway/fe.py:1123: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. There is/are 0 observation(s) with Pii above this threshold. These will be recomputed analytically. It took 5 batch(es) to get below the threshold of 1 bad observations.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 140.72it/s]
#  82%|███████████████████████████████████▎       | 41/50 [01:17<00:14,  1.63s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 201.06it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 199.07it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 105.73it/s]
#  84%|████████████████████████████████████       | 42/50 [01:18<00:12,  1.59s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 252.33it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 253.98it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 119.96it/s]
#  86%|████████████████████████████████████▉      | 43/50 [01:19<00:10,  1.51s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 189.00it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 179.22it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 5 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 96.10it/s]
#  88%|█████████████████████████████████████▊     | 44/50 [01:21<00:09,  1.56s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 241.79it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 230.85it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 129.64it/s]
#  90%|██████████████████████████████████████▋    | 45/50 [01:22<00:07,  1.48s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 173.19it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 174.67it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 90.23it/s]
#  92%|███████████████████████████████████████▌   | 46/50 [01:24<00:06,  1.60s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 194.86it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 179.26it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 82.21it/s]
#  94%|████████████████████████████████████████▍  | 47/50 [01:26<00:05,  1.70s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 169.23it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 153.45it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 2 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 81.12it/s]
#  96%|█████████████████████████████████████████▎ | 48/50 [01:28<00:03,  1.76s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 155.99it/s]
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 164.06it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 1 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 75.64it/s]
#  98%|██████████████████████████████████████████▏| 49/50 [01:30<00:01,  1.81s/it]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 206.67it/s]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 188.40it/s]
# ../../../pytwoway/fe.py:1127: UserWarning: Threshold for max Pii is 0.98, with 50 draw(s) per batch and a maximum of 5 batch(es) being drawn. After exhausting the maximum number of batches, there is/are still 4 draw(s) with Pii above this threshold. These will be recomputed analytically.
#   warnings.warn(leverage_warning)
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 84.42it/s]
# 100%|███████████████████████████████████████████| 50/50 [01:32<00:00,  1.84s/it]

# %% [markdown]
# ## Finally, plot parameter estimates (plots show the difference from the truth)

# %%
twmc.plot_monte_carlo(he=True)

# %%
twmc.plot_monte_carlo(he=False)
