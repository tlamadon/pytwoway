# %% [markdown]
# # BLM example

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Add pytwoway to system path, do not run this
import sys
sys.path.append('../../..')

# %%
# Import the pytwoway package 
# (Make sure you have installed it using pip install pytwoway)
import pytwoway as tw
import pandas as pd

# %% [markdown]
# ## Simulate some data
#
# The package contains functions to simulate data. We use this here to keep things simple.

# %%
# For the example, we simulate data
sim_model = tw.BLMModel({
    'nl': 6, # Number of worker types
    'nk': 10, # Number of firm types
    'simulation': True # Simulating data
})
sim_data = sim_model._m2_mixt_simulate_sim()
display(sim_data['jdata'])
display(sim_data['sdata'])
# Out:
#      l        y1        y2  j1  j2  j1true  j2true   f1  f2
# 0    2  0.369317  0.428335   0   0       0       0   F6  F5
# 1    1  0.179391  1.068883   0   0       0       0   F5  F6
# 2    0 -0.293172  0.401046   0   0       0       0   F1  F9
# 3    5  0.198402  0.751647   0   0       0       0   F5  F4
# 4    4  0.875508  0.218473   0   0       0       0   F4  F7
# ..  ..       ...       ...  ..  ..     ...     ...  ...  ..
# 995  3  1.636969  1.676450   9   9       9       9   F2  F1
# 996  4  1.683084  1.800596   9   9       9       9  F10  F2
# 997  1  1.323135  1.462752   9   9       9       9   F1  F4
# 998  2  2.249883  2.281154   9   9       9       9   F3  F4
# 999  2  2.015486  2.414283   9   9       9       9   F4  F4
#
# [1000 rows x 9 columns]
#     k        y1        y2  j1  j2  x   f1  j1true   f2
# 0   2 -0.233565  0.268999   0   0  1   F0       0   F0
# 1   1 -0.668797  0.392462   0   0  1   F0       0   F0
# 2   1  0.129065  1.003138   0   0  1   F0       0   F0
# 3   5  0.786237  0.204564   0   0  1   F0       0   F0
# 4   3 -0.110720  0.416532   0   0  1   F1       0   F1
# .. ..       ...       ...  ..  .. ..  ...     ...  ...
# 95  2  1.372111  2.011265   9   9  1   F9       9   F9
# 96  4  0.892515  2.707899   9   9  1   F9       9   F9
# 97  1  1.957556  1.489878   9   9  1  F10       9  F10
# 98  4  1.818067  2.403558   9   9  1   F9       9   F9
# 99  2  1.568831  1.543977   9   9  1   F9       9   F9
#
# [100 rows x 9 columns]

# %% [markdown]
# # Initialize and run BLMEstimator

# %%
## Optional Parameters ##
fit_params = {
    # Class parameters
    'nl': 6, # Number of worker types
    'nk': 10, # Number of firm types
    'fixb': False, # Set A2 = np.mean(A2, axis=0) + A1 - np.mean(A1, axis=0)
    'stationary': False, # Set A1 = A2
    'simulation': False, # If True, using model to simulate data
    # fit_movers() and fit_stayers() parameters
    'maxiters': 100, # Max number of iterations
    # fit_movers() parameters
    'update_a': True, # If False, do not update A1 or A2
    'update_s': True, # If False, do not update S1 or S2
    'return_qi': False, # If True, return qi matrix after first loop
    'cons_a': (['lin'], {'n_periods': 2}), # Constraints on A1 and A2
    'cons_s': (['biggerthan'], {'gap_bigger': 1e-4, 'n_periods': 2}), # Constraints on S1 and S2
    # fit_stayers() parameters
    'return_qi': False # If True, return qi matrix after first loop
}
# Initialize BLM estimator
BLM = tw.BLMEstimator()
# Fit BLM estimator
BLM.fit(jdata=sim_data['jdata'], sdata=sim_data['sdata'], iter=10, ncore=1, user_params=fit_params)
# Out:
# Running fixm movers
# loop 0, liks 13.91501419668086
# loop 1, liks 30.621111524238813
# loop 2, liks 29.928903855319852
# loop 3, liks 28.59499824672443
# loop 4, liks 27.466148503088288
# loop 5, liks 26.72883338146302
# loop 6, liks 26.32867493769072
# loop 7, liks 26.165666504363244
# loop 8, liks 26.119852342291342
# loop 9, liks 26.12358061760373
# loop 10, liks 26.15807624490479
# loop 11, liks 26.22298501851708
# loop 12, liks 26.326282005995047
# loop 13, liks 26.457690548958773
# loop 14, liks 26.59059330659693
# loop 15, liks 26.6971293688787
# loop 16, liks 26.76627539791065
# loop 17, liks 26.804476569634698
# loop 18, liks 26.82302237361867
# loop 19, liks 26.832460383484822
# loop 20, liks 26.846417954933322
# loop 21, liks 26.878253868615865
# loop 22, liks 26.899718892357562
# loop 23, liks 26.910013667328197
# loop 24, liks 26.92037990590982
# loop 25, liks 26.932810508572885
# loop 26, liks 26.94741358716823
# loop 27, liks 26.965774447905236
# loop 28, liks 27.001378788512202
# loop 29, liks 27.12236111877356
# loop 30, liks 27.264306073950234
# loop 31, liks 27.431635038937035
# loop 32, liks 27.518272723512137
# loop 33, liks 27.532612082401887
# loop 34, liks 27.53221142919167
# loop 35, liks 27.528851250229046
# loop 36, liks 27.524382659791392
# loop 37, liks 27.519264742746977
# loop 38, liks 27.513741897652444
# loop 39, liks 27.50804573493136
# loop 40, liks 27.502402983850835
# loop 41, liks 27.497006737630837
# loop 42, liks 27.492000393417932
# loop 43, liks 27.487475228804968
# loop 44, liks 27.483475319680064
# loop 45, liks 27.480006606671814
# loop 46, liks 27.477048237775634
# loop 47, liks 27.474564318177706
# loop 48, liks 27.472514239148264
# loop 49, liks 27.47086020020411
# loop 50, liks 27.469571270586655
# loop 51, liks 27.468624107491166
# loop 52, liks 27.46800104351349
# loop 53, liks 27.467686586649705
# loop 54, liks 27.467663474604272
# loop 55, liks 27.46790935935843
# loop 56, liks 27.468394998282534
# loop 57, liks 27.46908448280543
# loop 58, liks 27.469937552525504
# loop 59, liks 27.470913513894338
# loop 60, liks 27.471975880681345
# loop 61, liks 27.473096739365978
# loop 62, liks 27.474260052984693
# loop 63, liks 27.47546352581869
# loop 64, liks 27.47671903857048
# loop 65, liks 27.47805182797329
# loop 66, liks 27.479498418576647
# loop 67, liks 27.481102833343606
# loop 68, liks 27.48291002553872
# loop 69, liks 27.484955418231063
# loop 70, liks 27.487251169166782
# loop 71, liks 27.489774390300862
# loop 72, liks 27.492467756197
# loop 73, liks 27.495260381409455
# loop 74, liks 27.498101027709822
# loop 75, liks 27.500981120275164
# loop 76, liks 27.50393309009504
# loop 77, liks 27.507010761580915
# loop 78, liks 27.5102666317411
# loop 79, liks 27.51373462972648
# loop 80, liks 27.517420152593807
# loop 81, liks 27.52129649711464
# loop 82, liks 27.525306099593728
# loop 83, liks 27.529365062137032
# loop 84, liks 27.533370382659534
# loop 85, liks 27.5372105998129
# loop 86, liks 27.54078030797861
# loop 87, liks 27.54399638693379
# loop 88, liks 27.54681106745523
# loop 89, liks 27.549217680415545
# loop 90, liks 27.551249124429333
# loop 91, liks 27.552972216386465
# loop 92, liks 27.55447808270545
# loop 93, liks 27.555858748135712
# loop 94, liks 27.557160167215496
# loop 95, liks 27.558348297871152
# loop 96, liks 27.559355423654694
# loop 97, liks 27.560159406123507
# loop 98, liks 27.560793590372388
# loop 99, liks 27.561309569602994
# Running constrained movers
# loop 0, liks 27.56175206774428
# loop 1, liks 32.72546697848478
# loop 2, liks 35.26407482094703
# loop 3, liks 36.27739333238545
# loop 4, liks 38.311564949775914
# loop 5, liks 40.144793700086026
# loop 6, liks 40.73873486020137
# loop 7, liks 41.17969282310683
# loop 8, liks 41.79815732846361
# loop 9, liks 42.2960811041588
# loop 10, liks 42.47891777934985
# loop 11, liks 42.674776216614674
# loop 12, liks 42.977343376941974
# loop 13, liks 43.40555693907631
# loop 14, liks 43.85333633545539
# loop 15, liks 44.03202861465307
# loop 16, liks 44.10280101256065
# loop 17, liks 44.07730772263919
# loop 18, liks 41.32335024357697
# loop 19, liks 39.943326035191035
# loop 20, liks 42.322176935868484
# loop 21, liks 41.53236996127307
# loop 22, liks 43.18686681747693
# loop 23, liks 38.83001305641378
# loop 24, liks 39.98335758055016
# loop 25, liks 40.540887751332214
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-6c78542eac85> in <module>
#      21 BLM = tw.BLMEstimator()
#      22 # Fit BLM estimator
# ---> 23 BLM.fit(jdata=sim_data['jdata'], sdata=sim_data['sdata'], iter=10, ncore=1, user_params=fit_params)
#
# ~/Desktop/pytwoway/pytwoway/blm.py in fit(self, jdata, sdata, iter, ncore, user_params)
#     693         best_model = None
#     694
# --> 695         for model in sim_model_lst:
#     696             if model.liks1 > max_liks:
#     697                 max_liks = model.liks1
#
# ~/Desktop/pytwoway/pytwoway/blm.py in _sim_model(self, jdata, params)
#     675         '''
#     676         model = BLMModel(params)
# --> 677         model.fit_movers_cstr_uncstr(jdata)
#     678         return model
#     679
#
# ~/Desktop/pytwoway/pytwoway/blm.py in fit_movers_cstr_uncstr(self, jdata)
#     518         self.params['cons_a'] = (['lin'], {'n_periods': 2}) # Set constraints
#     519         print('Running constrained movers')
# --> 520         self.fit_movers(jdata)
#     521         ##### Loop 3 #####
#     522         self.params['cons_a'] = () # Remove constraints
#
# ~/Desktop/pytwoway/pytwoway/blm.py in fit_movers(self, jdata)
#     427             XwX = np.diag(XwXd)
#     428             if params['update_a']:
# --> 429                 cons_a.solve(XwX, - XwY)
#     430                 res_a = cons_a.res
#     431                 A1 = np.reshape(res_a, (2, nl, nk))[0, :, :].T
#
# ~/Desktop/pytwoway/pytwoway/blm.py in solve(self, P, q)
#     266             self.res = solve_qp(P=P, q=q, G=self.G, h=self.h)
#     267         elif len(self.A) > 0:
# --> 268             self.res = solve_qp(P=P, q=q, A=self.A, b=self.b)
#     269         else:
#     270             self.res = solve_qp(P=P, q=q)
#
# ~/opt/anaconda3/envs/twfe-env/lib/python3.7/site-packages/qpsolvers/__init__.py in solve_qp(P, q, G, h, A, b, lb, ub, solver, initvals, sym_proj, verbose, **kwargs)
#     260         return qpoases_solve_qp(*args, **kwargs)
#     261     elif solver == 'quadprog':
# --> 262         return quadprog_solve_qp(*args, **kwargs)
#     263     raise Exception("solver '%s' not recognized" % solver)
#     264
#
# ~/opt/anaconda3/envs/twfe-env/lib/python3.7/site-packages/qpsolvers/quadprog_.py in quadprog_solve_qp(P, q, G, h, A, b, initvals, verbose)
#      86         meq = 0
#      87     try:
# ---> 88         return solve_qp(qp_G, qp_a, qp_C, qp_b, meq)[0]
#      89     except ValueError as e:
#      90         if "matrix G is not positive definite" in str(e):
#
# quadprog/quadprog.pyx in quadprog.solve_qp()
#
# ValueError: constraints are inconsistent, no solution

# %% [markdown]
# # Finally, we can investigate the results

# %%
BLM.plot_A1()
